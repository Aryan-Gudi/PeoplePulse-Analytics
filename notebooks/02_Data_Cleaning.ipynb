# %% [markdown]
# # Data Cleaning
#
# ## Purpose
# Clean and format HR data for analysis.
#
# ## Business Objective
# Support the PeoplePulse Analytics initiative.
#
# ## Expected Input
# Raw data
#
# ## Expected Output
# Cleaned data
#
# ## Checklist
# - [ ] Load data
# - [ ] Process
# - [ ] Save results
