# %% [markdown]
# # Exploratory Data Analysis
#
# ## Purpose
# Find patterns and correlations in workforce data.
#
# ## Business Objective
# Support the PeoplePulse Analytics initiative.
#
# ## Expected Input
# Cleaned data
#
# ## Expected Output
# Insights, plots
#
# ## Checklist
# - [ ] Load data
# - [ ] Process
# - [ ] Save results
