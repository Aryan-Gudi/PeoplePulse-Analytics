# %% [markdown]
# # Data Understanding
#
# ## Purpose
# Understand the raw HR dataset.
#
# ## Business Objective
# Support the PeoplePulse Analytics initiative.
#
# ## Expected Input
# Raw HR data
#
# ## Expected Output
# Data profile, identified issues
#
# ## Checklist
# - [ ] Load data
# - [ ] Process
# - [ ] Save results
